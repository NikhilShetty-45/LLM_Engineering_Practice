# %% [markdown]
# # No Labs - Only Notes in Day 3

# %% [markdown]
# • LLMs come in 3 flavours
#
# 1. Base - Better for fine-tuning to learn a new skill
#
# 2. Chat/Instruct - Better for interactive use cases and creative content genearation
#
# 3. Reasoning/Thinking - Better for problem solving

# %% [markdown]
# • Frontier Models and their Chat Products
#
# 1. Open AI -> Models: GPT, Chat: ChatGPT
#
# 2. Anthropic -> Models: Claude, Chat: Claude
#
# 3. Google -> Models: Gemini, Chat: Gemini Advance
#
# 4. x.ai -> Models: Grok, Chat: Grok
#
# 5. Deepseel AI -> Models: Deepseek, Chat: Deepseek

# %% [markdown]
# • Mind Blowing performance from Frontier LLMs
#
# 1. Sysnthesizing information: Answering a question in deoth with a structured, well researched answer and other including a summary.
#
# 2. Fleshing out a skeleton: From a couple of notes, building out a well crafted email, or a blog post, and iterating on it with you until perfect.
#
# 3. Coding: The ability to write and debug code is remarakable ; far overtaken Stack overflow as the resource for engineer

# %% [markdown]
# • Limitations of frontier Model
#
# 1. Specialized domain : Most are not PhD level, but closing in
#
# 2. Recent events : Limited knowledge beyound training cut-off date, code oftern uses legacy APis/model
#
# 3. Confidently make mistakes : some curious blinspots. Can jump to conclusions when coding
