# %% [markdown]
# • Note :
# GPT = Generative pretrained Transformer

# %% [markdown]
# • Parameters :
# More paramter = More Intelligence = More Training done on the Models

# %% [markdown]
# # Tokens :

# %%
import tiktoken

encoding =  tiktoken.encoding_for_model("gpt-4.1-mini")

tokens = encoding.encode("My name is Nikhil")

# %%
tokens

# %%
for token_id in tokens:
    print(f"{token_id}: {encoding.decode([token_id])}")

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %%
from openai import OpenAI

openai = OpenAI()

# %%
messages = [
    {"role": "system", "content": "You are helpful assistant."},
    {"role": "user", "content": "My name is Nikhil."},
]

# %%
response = openai.chat.completions.create(
    model = "gpt-4o-mini",
    messages = messages
)

response.choices[0].message.content

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Nikhil!"},
    {"role": "assistant", "content": "Hi Nikhil! How can I assist you today?"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = openai.chat.completions.create(
    model = "gpt-4o-mini",
    messages = messages
)

response.choices[0].message.content
