# %% [markdown]
# ## Choosing the Right LLM

# %% [markdown]
# ## Basics(1) features of an LLM
#
# • Open/Closed source Model
#
# • Chat/ Reasoning/ Hybrid
#
# • Release date and Knowledge cut-off
#
# • Parameters
#
# • Training Tokens
#
# • Context Window

# %% [markdown]
# ## Basics(2) features of an LLM
#
# • Inference Code
#
#         Api Charge or Runtime compute
#
# • Training cost
#
# • Build cost
#
# • Time to Market
#
# • Rate Limits
#
# • Speed
#
# • Latency
#
# • Lincense

# %% [markdown]
# ## Chinchilla Scaling Law
#
# Number of parameters ~ propotional to the number of training tokens

# %% [markdown]
# ## Benchmark
#
# • GPQA - PdD Science Expertise
#
# • MMLU-PRO - Language Understanding
#
# • AIME - Math
#
# • LiveCode Bench - Coding
#
# • MuSR - Reasoning
#
# • HLE - Super-Human intelligence

# %% [markdown]
# ## Limitation of Benchmark
#
# • Training data Contamination
#
# • Not consistently applied
#
# • Too narrow in scope
#
# • Hard to measure nuanced reasoning
#
# • Saturation
#
# • Overfitting
