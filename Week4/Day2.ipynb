# %% [markdown]
# # AI Leaderboards

# %% [markdown]
# 1. Artificial Analysis - The Leaderboard - https://artificialanalysis.ai/
#
# 2. Vellum -  Includes API cost and context window - https://www.vellum.ai/llm-leaderboard?utm_source=google&utm_medium=organic
#
# 3. Scale.com - SEAL Leaderboards - https://scale.com/leaderboard
#
# 4. Hugging Face - Open Source Leaderboard
#
# 5. Live Bench - Contamination-free

# %% [markdown]
# ### LM Arena
#
# • Compare frontier and open-source models directly
#
# • Blind human evals based on head to head comparison
#
# • LLM are measured with an ELO-style score rating.
